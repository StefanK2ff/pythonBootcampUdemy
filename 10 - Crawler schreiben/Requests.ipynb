# %% [markdown]
# ## Das Requests - Modul
#
# In dieser Lektion lernst du:
#
# - Wie du eine Webseite herunterlädst, und dir den HTML-Code davon anzeigen kannst.
#
# Dazu verwendne wir das requests-Modul (http://docs.python-requests.org/en/master/).
#
# Wir werden folgende Seite crawlen: http://python.beispiel.programmierenlernen.io/index.php.

# %%
import requests

# %%
r = requests.get("http://python.beispiel.programmierenlernen.io/index.php")

# %%
print(r.status_code)
print(r.headers)
print(r.text)
# Out:
# 200
# {'Date': 'Thu, 09 Mar 2023 09:48:00 GMT', 'Server': 'Apache', 'Upgrade': 'h2c', 'Connection': 'Upgrade, Keep-Alive', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'br', 'Content-Length': '1534', 'Keep-Alive': 'timeout=15, max=100', 'Content-Type': 'text/html; charset=utf-8'}
# <!DOCTYPE html>
# <html lang="de">
#   <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <meta name="description" content="">
#     <meta name="author" content="">
#
#     <title>Crawler-Auflistung</title>
#
#     <!-- Bootstrap core CSS -->
#     <link href="./lib/bootstrap/css/bootstrap.min.css" rel="stylesheet">
#     <link href="./css/narrow-jumbotron.css" rel="stylesheet">
#   </head>
#
#   <body>
#
#     <div class="container">
#       <div class="header clearfix">
#         <nav>
#           <ul class="nav nav-pills float-right">
#             <li class="nav-item">
# ...

# %%
rh = requests.get("https://www.lehrstelle-handwerk.de/ausbildung/lehrstellenboerse-praktikumsboerse/lehrstelle-suchen?tx_fnxhwkhhlehrstellenboerse_start%5Baction%5D=start&tx_fnxhwkhhlehrstellenboerse_start%5Bcontroller%5D=Lehrstellenboerse&cHash=f4456da37b3a17578d880ccc6fa07626")
print(rh.text)
print("=======================================================")
print(rh.content)
# Out:
# <!DOCTYPE html><html lang="de-DE"><head><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><!-- This website is powered by TYPO3 - inspiring people to share! TYPO3 is a free open source Content Management Framework initially created by Kasper Skaarhoj and licensed under GNU/GPL. TYPO3 is copyright 1998-2023 of Kasper Skaarhoj. Extensions are copyright of their respective owners. Information and contribution at https://typo3.org/ --><meta name="generator" content="TYPO3 CMS"/><meta name="description" content="Du suchst einen Ausbildungsplatz im Handwerk? Hier findest du eine Liste mit freien Stellen."/><meta name="robots" content="index,follow"/><meta name="viewport" content="width=device-width,initial-scale=1"/><meta name="keywords" content="Ausbildung,Lehrstelle,Hamburg,Handwerk"/><meta name="twitter:card" content="summary"/><meta name="language" content="de, at, ch, deutsch, german"/><meta name="audience" content="All, Alle"/><meta name="distribution" content="Globa
# ...
